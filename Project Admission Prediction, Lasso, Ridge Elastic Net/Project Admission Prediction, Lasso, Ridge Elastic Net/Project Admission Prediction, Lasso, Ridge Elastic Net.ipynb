# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV,ElasticNet,ElasticNetCV,LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\sudhir\AppData\Local\Temp\ipykernel_9896\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
pf = ProfileReport(df)
pf.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.drop(columns=['Serial No.'])
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.drop(columns=['Serial No.'],inplace=True)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df["University Rating"]
# Out:
# 0      4
# 1      4
# 2      3
# 3      3
# 4      2
#       ..
# 395    3
# 396    3
# 397    4
# 398    3
# 399    4
# Name: University Rating, Length: 400, dtype: int64

# %%
df.rename(columns = {'Chance of Admit ':'Chance of Admit'}, inplace = True)

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
y=df['Chance of Admit']
x=df.drop(columns=['Chance of Admit'])

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit, Length: 400, dtype: float64

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
scaler=StandardScaler() #Means mean=0 and std=1

# %%
scaler.fit_transform(x)
# Out:
# array([[ 1.76210664,  1.74697064,  0.79882862, ...,  1.16732114,
#          1.76481828,  0.90911166],
#        [ 0.62765641, -0.06763531,  0.79882862, ...,  1.16732114,
#          0.45515126,  0.90911166],
#        [-0.07046681, -0.56252785, -0.07660001, ...,  0.05293342,
#         -1.00563118,  0.90911166],
#        ...,
#        [ 1.15124883,  1.41704229,  0.79882862, ...,  1.16732114,
#          1.42900622,  0.90911166],
#        [-0.41952842, -0.72749202, -0.07660001, ...,  0.61012728,
#          0.30403584, -1.09997489],
#        [ 1.41304503,  1.58200646,  0.79882862, ...,  0.61012728,
#          1.78160888,  0.90911166]])

# %%
arr1=scaler.fit_transform(x)
arr1
# Out:
# array([[ 1.76210664,  1.74697064,  0.79882862, ...,  1.16732114,
#          1.76481828,  0.90911166],
#        [ 0.62765641, -0.06763531,  0.79882862, ...,  1.16732114,
#          0.45515126,  0.90911166],
#        [-0.07046681, -0.56252785, -0.07660001, ...,  0.05293342,
#         -1.00563118,  0.90911166],
#        ...,
#        [ 1.15124883,  1.41704229,  0.79882862, ...,  1.16732114,
#          1.42900622,  0.90911166],
#        [-0.41952842, -0.72749202, -0.07660001, ...,  0.61012728,
#          0.30403584, -1.09997489],
#        [ 1.41304503,  1.58200646,  0.79882862, ...,  0.61012728,
#          1.78160888,  0.90911166]])

# %%
df1=pd.DataFrame(arr1)

# %%
from pandas_profiling import ProfileReport
pf1 = ProfileReport(df1)
pf1.to_widgets()
# Out:
# C:\Users\sudhir\AppData\Local\Temp\ipykernel_4544\2809288943.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
df1
# Out:
#             0         1         2         3         4         5         6
# 0    1.762107  1.746971  0.798829  1.093864  1.167321  1.764818  0.909112
# 1    0.627656 -0.067635  0.798829  0.596653  1.167321  0.455151  0.909112
# 2   -0.070467 -0.562528 -0.076600 -0.397769  0.052933 -1.005631  0.909112
# 3    0.453126  0.427257 -0.076600  0.099442 -1.061454  0.119339  0.909112
# 4   -0.244998 -0.727492 -0.952029 -1.392191 -0.504260 -0.653029 -1.099975
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.627656  0.427257 -0.076600  0.099442  0.052933  0.740592  0.909112
# 396  0.714922 -0.067635 -0.076600 -0.397769  0.052933  0.858126  0.909112
# 397  1.151249  1.417042  0.798829  1.591075  1.167321  1.429006  0.909112
# 398 -0.419528 -0.727492 -0.076600  0.099442  0.610127  0.304036 -1.099975
# 399  1.413045  1.582006  0.798829  1.591075  0.610127  1.781609  0.909112
#
# [400 rows x 7 columns]

# %%
df1.describe()
# Out:
#                   0             1             2             3             4  \
# count  4.000000e+02  4.000000e+02  4.000000e+02  4.000000e+02  4.000000e+02
# mean  -3.785861e-16  5.412337e-16  7.147061e-16  1.859624e-16 -3.019807e-16
# std    1.001252e+00  1.001252e+00  1.001252e+00  1.001252e+00  1.001252e+00
# min   -2.339367e+00 -2.542098e+00 -1.827457e+00 -2.386613e+00 -2.733036e+00
# 25%   -7.685900e-01 -7.274920e-01 -9.520286e-01 -8.949798e-01 -5.042604e-01
# 50%    1.679859e-02 -6.763531e-02 -7.660001e-02  9.944220e-02  5.293342e-02
# 75%    7.149218e-01  7.571856e-01  7.988286e-01  5.966532e-01  6.101273e-01
# max    2.023903e+00  2.076899e+00  1.674257e+00  1.591075e+00  1.724515e+00
#
#                   5             6
# count  4.000000e+02  4.000000e+02
# mean   8.076873e-16  2.942091e-17
# std    1.001252e+00  1.001252e+00
# min   -3.020504e+00 -1.099975e+00
# 25%   -7.201909e-01 -1.099975e+00
# 50%    1.859559e-02  9.091117e-01
# 75%    7.783704e-01  9.091117e-01
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
arr1.shape
# Out:
# (400, 7)

# %%
[variance_inflation_factor(arr1,i) for i in range(arr1.shape[1])]
# Out:
# [4.615516166781608,
#  4.288959013746899,
#  2.9196056618253414,
#  3.075503721954348,
#  2.431258484869441,
#  5.207402545736424,
#  1.5433119011502878]

# %%
vif_df=pd.DataFrame()
vif_df['vif']=[variance_inflation_factor(arr1,i) for i in range(arr1.shape[1])]

# %%
vif_df['feature']=x.columns

# %%
vif_df #VIF is less than equal to 10 so we can not drop any columns. IF greater than 10 then apply PCA and t-SNE(Starand Scalar Technique.).
# Out:
#         vif            feature
# 0  4.615516          GRE Score
# 1  4.288959        TOEFL Score
# 2  2.919606  University Rating
# 3  3.075504                SOP
# 4  2.431258               LOR
# 5  5.207403               CGPA
# 6  1.543312           Research

# %%
x_train, x_test, y_train, y_test=train_test_split(arr1, y, test_size=0.25, random_state=1)

# %%
x_train
# Out:
# array([[ 0.2785948 ,  0.42725722,  1.67425725, ...,  1.16732114,
#          1.04282236,  0.90911166],
#        [-0.50679383, -1.55231291, -1.82745726, ..., -1.06145431,
#         -1.91232372, -1.09997489],
#        [-0.85585544, -0.8924562 , -0.07660001, ..., -0.50426044,
#         -0.5522849 , -1.09997489],
#        ...,
#        [ 0.71492181, -0.06763531, -0.07660001, ...,  0.05293342,
#          0.85812573,  0.90911166],
#        [ 0.80218721,  0.5922214 ,  1.67425725, ...,  0.61012728,
#          1.05961296,  0.90911166],
#        [-1.46671326, -0.39756367, -1.82745726, ..., -1.61864817,
#         -1.34144323, -1.09997489]])

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 0.01628378,  0.01730007,  0.00902026, -0.00259041,  0.01870585,
#         0.06790342,  0.01422411])

# %%
lr.intercept_
# Out:
# 0.726937071743013

# %%
import pickle
pickle.dump(lr,open('admission_lr_model.pickle','wb'))

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# ...

# %%
lr.predict([[337,118,4,4.5,4.5,9.65,1]]) #Now score is 9.03 but range is 0 to 1. It means whatever StanderScalar you do for traing dataset you must do same StanderScalar for prediction dataset so that you will get actual result.
# Out:
# array([9.03407258])

# %% [markdown]
# #### test1

# %%
scaler.transform([[337,118,4,4.5,4.5,9.65,1]])# <---1st row
#Note- You must create same object for actual result.
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[1.76210664, 1.74697064, 0.79882862, 1.09386422, 1.16732114,
#         1.76481828, 0.90911166]])

# %%
lr.predict([[1.76210664, 1.74697064, 0.79882862, 1.09386422, 1.16732114,
        1.76481828, 0.90911166]]) #Now finally you got actual  approx result.
# Out:
# array([0.94482986])

# %% [markdown]
# #### test2

# %%
test2=scaler.transform([[337,118,4,4.5,4.5,9.65,1]])# <----last row
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
lr.predict(test2)
# Out:
# array([0.94482987])

# %% [markdown]
# #### Using given model

# %%
test2=scaler.transform([[337,118,4,4.5,4.5,9.65,1]])# <----last row
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model=pickle.load(open('admission_lr_model.pickle','rb'))

# %%
model.predict(test2)
# Out:
# array([0.94482987])

# %% [markdown]
# #### accuracy

# %%
lr.score(x_test,y_test) # This is R^2.
# Out:
# 0.8163951846360171

# %%
# Lets create a function to create adjected-R^2
def adj_r2(x,y):
    r2=lr.score(x,y)
    n=x.shape[0]
    p=x.shape[1]
    adjected_r2=1-(1-r2)*(n-1)/(n-p-1)
    return adjected_r2

# %%
adj_r2(x_test,y_test)
# Out:
# 0.8024252530322358

# %% [markdown]
# #### Some experiment

# %%
# We change random_state we get different result inc or dec acc.
# We do some kind of changing in test_size then we get different result inc or dec acc.

# %% [markdown]
# ### Lasso
# alpha is lambda.

# %%
lassocv=LassoCV(alphas=None, cv= 10, max_iter=2000000, normalize=True)
lassocv.fit(x_train,y_train)
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# LassoCV(cv=10, max_iter=2000000, normalize=True)

# %%
lassocv.alpha_
# Out:
# 3.481563880691118e-05

# %%
lasso=Lasso(alpha=lassocv.alpha_)
lasso
# Out:
# Lasso(alpha=3.481563880691118e-05)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=3.481563880691118e-05)

# %%
lasso.score(x_test,y_test)
# Out:
# 0.8163473673643156

# %% [markdown]
# #### Note-
# Acc. is increses here when we use lasoCV.

# %% [markdown]
# ### Ridge

# %%
ridgecv=RidgeCV(alphas=(0.1, 1.0, 10.0),cv=10,normalize=True)
ridgecv
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=10, normalize=True)

# %%
ridgecv.fit(x_train,y_train)
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
#for simplicity
#ridgecv=RidgeCV(alphas=(0.1, 1.0, 10.0),cv=10,normalize=True)
#ridgecv.fit(x_train,y_train)

# %%
ridgecv.alpha_
# Out:
# 0.1

# %%
ridgecv=RidgeCV(alphas=np.random.uniform(0,10,50),cv=10,normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\sudhir\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
ridgecv.alpha_
# Out:
# 0.18298738134962855

# %%
rigid_lr=Ridge(alpha=ridgecv.alpha_)
rigid_lr
# Out:
# Ridge(alpha=0.18298738134962855)

# %%
rigid_lr.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.18298738134962855)

# %%
rigid_lr.score(x_test,y_test)
# Out:
# 0.8163381819240411

# %% [markdown]
# ### Elastic_Net

# %%
elastic=ElasticNetCV(alphas=None,cv=10)
elastic
# Out:
# ElasticNetCV(cv=10)

# %%
elastic.fit(x_train,y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
#for simplicity
#elastic=ElasticNetCV(alphas=None,cv=10)
#elastic.fit(x_train,y_train)

# %%
elastic.alpha_
# Out:
# 0.001119953394121576

# %%
elastic.l1_ratio_
# Out:
# 0.5

# %%
elastic_lr=ElasticNet(alpha=elastic.alpha_, l1_ratio=elastic.l1_ratio_)
elastic_lr
# Out:
# ElasticNet(alpha=0.001119953394121576)

# %%
elastic_lr.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.001119953394121576)

# %%
elastic_lr.score(x_test,y_test)
# Out:
# 0.8155001959703047

# %%
# Conclusion so model is not overfitted.
